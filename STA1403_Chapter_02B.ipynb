# %% [markdown]
# <a href="https://colab.research.google.com/github/DavidSenseman/STA1403/blob/main/STA1403_Chapter_02B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <!-- STA1403_CHAPTER_02B:Rev 1 -->

# %% [markdown]
# ---------------------------
# **COPYRIGHT NOTICE:** This Jupyterlab Notebook is a Derivative work of [Jeff Heaton](https://github.com/jeffheaton) licensed under the Apache License, Version 2.0 (the "License"); You may not use this file except in compliance with the License. You may obtain a copy of the License at
#
# > [http://www.apache.org/licenses/LICENSE-2.0](http://www.apache.org/licenses/LICENSE-2.0)
#
# Unless required by applicable law or agreed to in writing, software distributed under the License is distributed on an "AS IS" BASIS, WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied. See the License for the specific language governing permissions and limitations under the License.
#
# ------------------------

# %% [markdown]
# # **STA 1403: Biostatistics**

# %% [markdown]
# ## **Chapter 2: Data Exploration**
#
# Instructor: [David Senseman](mailto:David.Senseman@utsa.edu), [Department of Biology, Health and the Environment](https://sciences.utsa.edu/bhe/), [UT San Antonio](https://www.utsa.edu/)
#
# #### Contents
# * 2.1 : Data Visualization and Summary Statistics
# * 2.2 : Variable Types
# * 2.3 : Exploring Categorical Variables
# * 2.4 : Exploring Numerical Variables
# * **2.5 : Data Processing**
# * **2.6 : Advanced**

# %% [markdown]
# ## Google Colab Instructions
#
# Run next code cell to map this Colab lesson's folder /content/drive to your Google Drive. This will allow you keep a copy of this Colab notebook which is **_your_** course textbook.

# %%
# @title **Run this cell first**
try:
    from google.colab import drive
    drive.mount('/content/drive', force_remount=True)
    Colab = True
    print("Note: Using Google CoLab")
    # !curl ipinfo.io
except:
    print("**WARNING**: Your GDrive is not mapped to /content/drive ")
    print("**WARNING**: Your work will not be saved!")
    Colab = False
# Out:
# Mounted at /content/drive
# Note: Using Google CoLab
# {
#   "ip": "34.125.209.236",
#   "hostname": "236.209.125.34.bc.googleusercontent.com",
#   "city": "Las Vegas",
#   "region": "Nevada",
#   "country": "US",
#   "loc": "36.1750,-115.1372",
#   "org": "AS396982 Google LLC",
#   "postal": "89158",
#   "timezone": "America/Los_Angeles",
#   "readme": "https://ipinfo.io/missingauth"
# }

# %% [markdown]
# You should see something _similar_ to the following output:
# ```text
# Mounted at /content/drive
# Note: Using Google CoLab
# {
#   "ip": "34.139.115.187",
#   "hostname": "187.115.139.34.bc.googleusercontent.com",
#   "city": "North Charleston",
#   "region": "South Carolina",
#   "country": "US",
#   "loc": "32.8546,-79.9748",
#   "org": "AS396982 Google LLC",
#   "postal": "29415",
#   "timezone": "America/New_York",
#   "readme": "https://ipinfo.io/missingauth"
# }
# ```

# %% [markdown]
# ## Test Your STA1403 Key
#
# Run the next cell to test whether your STA1403 Key is correctly installed in your Colab Secrets.

# %%
# @title Test Your STA1403 Key

from google.colab import userdata
import os

# Check if key is properly loaded
try:
    # 1. Get the key from Secrets
    STA1403_KEY = userdata.get('STA1403_KEY')

    # 2. Set it as an environment variable
    os.environ['STA1403_KEY'] = STA1403_KEY

    print("STA1403 key loaded and environment variable set successfully!")
    print(f"Key length: {len(STA1403_KEY)}")

except Exception as e:
    print(f"Error loading STA1403 key: {e}")
    print("Please set your STA1403 key in Google Colab:")
    print("1. Go to Secrets in the left sidebar (key icon)")
    print("2. Create a new secret named 'STA1403_KEY'")
    print("3. Paste your STA1403 key and toggle 'Notebook access' on")
# Out:
# STA1403 key loaded and environment variable set successfully!
# Key length: 26

# %% [markdown]
# If your STA1403 key is correctly stored in your Colab Secrets, you should see something _similar_ to the following output:
# ```text
# STA1403 key loaded and environment variable set successfully!
# Key length: 28
# ```
# If you recieve an error and you are unable to resolve the problem yourself, you will need to contact the Instructor or TA for help. You will not be able to submit this notebook for grading without your STA1403 Key.

# %% [markdown]
# # **Chapter 2 : Data Exploration**
#
# ## **2.5 Data Prepocessing**
#
# Many of the data sets we have been using as examples have been collected in scientific studies. Typically, such data are not ready for immediate analysis. The most common issues are missing values and outliers. For example, the original data on women of Pima Indian Heritage (collected by US National Institute of Diabetes and Digestive and Kidney Diseases) included many observations with missing values. The data set we have been using so far (Pima.tr) was obtained after removing these observations. We refer to data in their original form (i.e., collected by researchers) as the raw data. Before using the original data for analysis, we should thoroughly check them for missing values and possible outliers. Data exploration techniques we discussed in this chapter can help us to identify data issues that need to be addressed before further analysis. Collectively, we refer to the process of preparing the raw data for analysis as data preprocessing. Here, we discuss some simple preprocessing steps.
#
# We begin by reading the same two datafiles used in Part A of Chapter 2, the `birthwt` data set and the `Pima.tr` data set.

# %% [markdown]
# ## Example 1: Read a Datafile and View Its Contents
#
# The code in the cell below uses a command called `pd.read_csv()` to read a data file from the course file server `https://biologicslab.co`. In this example, the name of the file is `"birthwt"`.
#
# In addition to the data file name, one additional argument is passed, the data separator character, in this file, the data separator is a comma `sep=','`.
#
# The command starts with `birthwt_df =` to tell Python to store what it reads in a **DataFrame** called `birthwt_df`.
#
# We had also add an additional argument to the command that reads the datafile:`na_values=["?", "NA", "null", ""]`. This additional argument is necessary to keep any missing values.
#
# To see what is stored in our `birthwt_df` at a certain location in the DataFrame, we can use this command birthwt__df.iloc[20:30]. This will let us look at the 10 records.

# %%
# @title Example 1: Create Dataframe from File Download

import pandas as pd

# ── INPUT SECTION ─────────────────────────────────────────────────────────────
FILE_NAME    = "birthwt"      # File name
DATA_SEP     = ","            # Data separator
# ──────────────────────────────────────────────────────────────────────────────

# Build file path
datafile ="https://biologicslab.co/STA1403/data/"+ FILE_NAME

# Store datafile in dataframe
df_bwt = pd.read_csv(datafile, sep=DATA_SEP)

# Print out selected records in dataframe
df_bwt.iloc[20:30]
# Out:
#     low  age    lwt   race  smoke  ptl  ht  ui  ftv   bwt
# 20    0   32  121.0  other      0    0   0   0    2  2835
# 21    0   31  100.0  white      0    0   0   1    3  2835
# 22    0   36  202.0  white      0    0   0   0    1  2836
# 23    0   28  120.0  other      0    0   0   0    0  2863
# 24    0   25  120.0  other      0    0   0   1    2  2877
# 25    0   28  167.0  white      0    0   0   0    0  2877
# 26    0   17  122.0  white      1    0   0   0    0  2906
# 27    0   29  150.0  white      0    0   0   0    2  2920
# 28    0   26  168.0  black      1    0   0   0    0  2920
# 29    0   17  113.0  black      0    0   0   0    1  2920

# %% [markdown]
# If the code is correct, you should see the following output:
# ![__](https://biologicslab.co/STA1403/images/chapter_02/chapter_02B_image13A.png)

# %% [markdown]
# ## **Exercise 1A: Read a Datafile and View Its Contents**
#
# In the cell below, write the code to read a file called `Pima.tr` and display 6 records starting at record 20.
#
# **Code Hints:**
# 1. Copy-and-paste Example 1 into the cell below.
# 2. Change the variables to look like this code block:
# ```Python
# # ── INPUT SECTION ─────────────────────────────────────────────────────────────
# FILE_NAME    = "Pima.tr"   # File name
# DATA_SEP     = ","         # Data separator
# TITLE        = "Fig.2.1 Viewing the `Pima.tr` data using Python"   # Title
# # ──────────────────────────────────────────────────────────────────────────────
# ```
# 3. Change every instance of `df_bwt` to `df_pima`.

# %%
# @title Exercise 1A: Download a Datafile and View Its Contents

import pandas as pd

# ── INPUT SECTION ─────────────────────────────────────────────────────────────
FILE_NAME    = "Pima.tr"   # File name
DATA_SEP     = ","         # Data separator
# ──────────────────────────────────────────────────────────────────────────────

# Build file path
datafile ="https://biologicslab.co/STA1403/data/"+ FILE_NAME

# Store datafile in dataframe
df_pima = pd.read_csv(datafile, sep=DATA_SEP)

# Print out selected records in dataframe
df_pima.iloc[20:30]
# Out:
#     npreg  glu  bp  skin   bmi    ped  age type
# 20      2   99  70    16  20.4  0.235   27   No
# 21      1  100  66    29  32.0  0.444   42   No
# 22      4   83  86    19  29.3  0.317   34   No
# 23      0  101  64    17  21.0  0.252   21   No
# 24      1   87  68    34  37.6  0.401   24   No
# 25      9  164  84    21  30.8  0.831   32  Yes
# 26      1   99  58    10  25.4  0.551   21   No
# 27      0  140  65    26  42.6  0.431   24  Yes
# 28      5  108  72    43  36.1  0.263   33   No
# 29      2  110  74    29  32.4  0.698   27   No

# %% [markdown]
# If your code is correct, you should see the following output:
#
# ![__](https://biologicslab.co/STA1403/images/chapter_02/chapter_02B_image01B.png)

# %% [markdown]
# ## **Exercise 1B: Read a Datafile and View Its Contents**
#
# In the cell below, write the code to read a file called `Pima.tr` and display 6 records starting at record 20.
#
# **Code Hints:**
# 1. Copy-and-paste Example 1 into the cell below.
# 2. Change the variables to read as in the following code block:
# ```Python
# # Define variables
# file_server = "https://biologicslab.co"
# file_dir = "/STA1403/data/"
# file_name = "AsthmaLOS.txt"
# df_name = "asthma_df"
# file_sep = "\t"
# ````

# %%
# @title Exercise 1B: Create Dataframe from File Download

import pandas as pd

# ── INPUT SECTION ─────────────────────────────────────────────────────────────
FILE_NAME    = "AsthmaLOS.txt"   # File name
DATA_SEP     = "\t"               # Data separator
# ──────────────────────────────────────────────────────────────────────────────

# Build file path
datafile ="https://biologicslab.co/STA1403/data/"+ FILE_NAME

# Store datafile in dataframe
df_asthma = pd.read_csv(datafile, sep=DATA_SEP)

# Print out selected records in dataframe
df_asthma.iloc[20:30]
# Out:
#     los  hospital.id  insurer  age  gender  race  bed.size  owner.type  \
# 20    1           57        0    3       0     1         2           1
# 21    2           57        0    4       1     5         2           1
# 22    1           57        0    2       0     2         2           1
# 23    2           57        0    9       1     2         2           1
# 24    4            3        0    2       0     1         2           2
# 25    2            3        0    3       0     1         2           2
# 26    3            3        0   11       0     1         2           2
# 27    5            3        0    2       1     1         2           2
# 28    2            3        0    3       0     1         2           2
# 29    6            3        0    7       0     1         2           2
#
#     complication
# 20             0
# 21             0
# 22             0
# 23             0
# 24             0
# 25             0
# 26             0
# 27             0
# 28             0
# ...

# %% [markdown]
# If your code is correct, you should see the following output:
#
# ![__](https://biologicslab.co/STA1403/images/chapter_02/chapter_02B_image03B.png)

# %% [markdown]
# ## **_2.5.1 Missing Data_**
#
# Missing values are a reality of statistical analysis. Ideally, every row of data will have values for all columns.  However, this is rarely the case. Replacing missing values is important in statistics because they can cause problems with analytical procedures and can lead to incorrect predictions. It is up to you to **_clean your data!_**
#
# There are a few different ways to deal with missing data. You could simply delete any record (i.e. the entire row) if it contained one (or more) missing value(s). This may or may not be reasonable depending upon the data set and the number of missing values in it.
#
# An alternative approach is to replace missing value(s) with the **median** value for that column. Here is the Wiki page for the program that calculates the [median](https://en.wikipedia.org/wiki/Median).
#
# In general, it is up to the researcher to decide whether to remove the observations with missing values or impute (guess) the missing values in order to keep the observations. Here we are going to show how to impute the median value for any missing values.

# %% [markdown]
# ## Example 2: Find Missing Values
#
# When working with a new dataset you should perform a quick check for any missing values. The example below, uses the Pandas method `df.isnull()` to locate any missing values in the `df_bwt` DataFrame.

# %%
# @title Example 2: Find Missing Values

import pandas as pd

# Identify whether each column contains missing values
missing_locations = df_bwt.isnull().any()

# Create a DataFrame that pairs column names with the missing‑flag
summary_df = pd.DataFrame({
    'column_name': df_bwt.columns,
    'has_missing': missing_locations
})

print(summary_df.to_string(index=False))
# Out:
# column_name  has_missing
#         low        False
#         age        False
#         lwt         True
#        race        False
#       smoke        False
#         ptl        False
#          ht        False
#          ui        False
#         ftv        False
#         bwt        False

# %% [markdown]
# If the code is correct, you should see the following output:
# ```text
# column_name  has_missing
#         low        False
#         age        False
#         lwt         True
#        race        False
#       smoke        False
#         ptl        False
#          ht        False
#          ui        False
#         ftv        False
#         bwt        False
# ```

# %% [markdown]
# If you scan down the column on the right called `has_missing`, you see that there is only one column where the value is `True`. That column is called `lwt`, and it must have one (or more) missing values.

# %% [markdown]
# ## **Exercise 2: Find Missing Values**
#
# Use the Python method `df.isnull().any()` to see if the `Pima` data has any missing values.
#
# **Code Hints:**
# 1. Copy-and-paste Example 1 into the cell below.
# 2. Change every instance of `df_bwt` to `df_pima`.

# %%
# @title Exercise 2: Find Missing Values

import pandas as pd

# Identify whether each column contains missing values
missing_locations = df_pima.isnull().any()

# Create a DataFrame that pairs column names with the missing‑flag
summary_df = pd.DataFrame({
    'column_name': df_pima.columns,
    'has_missing': missing_locations
})

print(summary_df.to_string(index=False))
# Out:
# column_name  has_missing
#       npreg        False
#         glu        False
#          bp        False
#        skin        False
#         bmi         True
#         ped        False
#         age        False
#        type        False

# %% [markdown]
# If your code is correct, you should see the following output:
# ```text
# column_name  has_missing
#       npreg        False
#         glu        False
#          bp        False
#        skin        False
#         bmi         True
#         ped        False
#         age        False
#        type        False
# ```

# %% [markdown]
# In the `Pima` DataFrame, there is one (or more) missing values in the column `bmi`. You will be asked to replace any missing values for `bmi` in **Exercise 3** below.

# %% [markdown]
# ## Example 3: Replace Missing Values
#
# Now that the location of the missing value(s) has been determined, the Pandas method `df.fillna()` can be used to replace the missing values.
#
# The first step is to compute the median value for the column using the Pandas method `median()`. The `median` represents our "best guess" of what the missing value would have been.
#
# The next step is to use `df.fillna()` to replace all of the missing values in the `lwt` column with the column's median value. Finally, we check once more for any missing values to make sure there are no more missing values.

# %%
# @title Example 3: Replace Missing Values

import pandas as pd

# ------------------------------------------------------------------------
# 1️⃣  Define variables
# ------------------------------------------------------------------------
col_name = 'lwt'

# ------------------------------------------------------------------------
# 2️⃣  Pick the column that contains missing values
# ------------------------------------------------------------------------
if col_name not in df_bwt.columns:
    raise ValueError(f"Column '{col_name}' not found!")

print(f"\nColumn with missing data is {col_name}")

# ------------------------------------------------------------------------
# 3️⃣  Compute the median (ignoring NaNs by default)
# ------------------------------------------------------------------------
missing_val_med = df_bwt[col_name].median()
print(f"The median value of the missing datapoint = {missing_val_med:.4f}.")
print(f"Replacing missing values with {missing_val_med:.4f}.\n")

# ------------------------------------------------------------------------
# 4️⃣   Fill the NaNs
# ------------------------------------------------------------------------
df_bwt[col_name] = df_bwt[col_name].fillna(missing_val_med)

# ------------------------------------------------------------------------
# 5️⃣  Verify no more missing values in that column
# ------------------------------------------------------------------------
missing_locations = df_bwt.isnull().any()
summary_df = pd.DataFrame({
    'column_name': df_bwt.columns,
    'has_missing': missing_locations
})

# ------------------------------------------------------------------------
# 6️⃣  Print summary
# ------------------------------------------------------------------------
print("After filling, check which columns still contain missing values:")
print(summary_df.to_string(index=False))
# Out:
# Column with missing data is lwt
# The median value of the missing datapoint = 121.0000.
# Replacing missing values with 121.0000.
#
# After filling, check which columns still contain missing values:
# column_name  has_missing
#         low        False
#         age        False
#         lwt        False
#        race        False
#       smoke        False
#         ptl        False
#          ht        False
#          ui        False
#         ftv        False
#         bwt        False

# %% [markdown]
# IF the code is correct, you should see the following output:
# ```text
# Column with missing data is lwt
# The median value of the missing datapoint = 121.0000.
# Replacing missing values with 121.0000.
#
# After filling, check which columns still contain missing values:
# column_name  has_missing
#         low        False
#         age        False
#         lwt        False
#        race        False
#       smoke        False
#         ptl        False
#          ht        False
#          ui        False
#         ftv        False
#         bwt        False
#
# ```

# %% [markdown]
# From the output you can see that the median value for the variable (`lwt`) 121.000. This median value (our best "guess") was used to replace all of missing `lwt` values in the `birthwt_df` DataFrame. Checking for missing values after replacement showq that all of the missing values had been replaced.

# %% [markdown]
# ## **Exercise 3: Replace Missing Values**
#
# In the cell below, write the code replace any missing values in the `Pima` DataFrame with their median values.
#
# **Code Hints:**
#
# 1. Copy-and-paste Example 3 into the cell below.
# 2. Change the variables as shown in this code block:
# ```Python
# # ------------------------------------------------------------------------
# # 1️⃣  Define variables
# # ------------------------------------------------------------------------
# col_name = 'bmi'
# ```
# 3. Change every instance of `df_bwt` to `df_pima`.

# %%
# @title Exercise 3: Replace Missing Values
import pandas as pd

# ------------------------------------------------------------------------
# 1️⃣  Define variables
# ------------------------------------------------------------------------
col_name = 'bmi'

# ------------------------------------------------------------------------
# 2️⃣  Pick the column that contains missing values
# ------------------------------------------------------------------------
if col_name not in df_pima.columns:
    raise ValueError(f"Column '{col_name}' not found!")

print(f"\nColumn with missing data is {col_name}")

# ------------------------------------------------------------------------
# 3️⃣  Compute the median (ignoring NaNs by default)
# ------------------------------------------------------------------------
missing_val_med = df_pima[col_name].median()
print(f"The median value of the missing datapoint = {missing_val_med:.4f}.")
print(f"Replacing missing values with {missing_val_med:.4f}.\n")

# ------------------------------------------------------------------------
# 4️⃣   Fill the NaNs
# ------------------------------------------------------------------------
df_pima[col_name] = df_pima[col_name].fillna(missing_val_med)

# ------------------------------------------------------------------------
# 5️⃣  Verify no more missing values in that column
# ------------------------------------------------------------------------
missing_locations = df_pima.isnull().any()
summary_df = pd.DataFrame({
    'column_name': df_pima.columns,
    'has_missing': missing_locations
})

# ------------------------------------------------------------------------
# 6️⃣  Print summary
# ------------------------------------------------------------------------
print("After filling, check which columns still contain missing values:")
print(summary_df.to_string(index=False))
# Out:
# Column with missing data is bmi
# The median value of the missing datapoint = 32.8000.
# Replacing missing values with 32.8000.
#
# After filling, check which columns still contain missing values:
# column_name  has_missing
#       npreg        False
#         glu        False
#          bp        False
#        skin        False
#         bmi        False
#         ped        False
#         age        False
#        type        False

# %% [markdown]
# If your code is correct, you should see the following output:
# ```text
# Column with missing data is bmi
# The median value of the missing datapoint = 32.8000.
# Replacing missing values with 32.8000.
#
# After filling, check which columns still contain missing values:
# column_name  has_missing
#       npreg        False
#         glu        False
#          bp        False
#        skin        False
#         bmi        False
#         ped        False
#         age        False
#        type        False
# ```

# %% [markdown]
# In this instance, the median value for the variable `bmi` (body mass index) is $32.8$. This value was used as a replacement for any record in the DataFrame `Pima_df` in which a value for `bmi` was missing.
#
# While simply removing observations with missing values is an easy approach for handling missing data, it is quite wasteful and inefficient. On the other hand, missing data imputation techniques, i.e., using statistical methods to fill-in missing values, tend to be complex. However, if done properly, they can improve our analysis.
#
# For an overview of statistical methods for analyzing data with missing values, refer to: Little, R.J.A., Rubin, D.B.: _Statistical Analysis with Missing Data_, 2nd edn. Wiley Interscience, New York (2002).

# %% [markdown]
# ### **_2.5.2 Outliers_**
#
# Dealing with missing values is not the only challenge of working with raw data. Sometimes, an observed value of a variable is suspicious since it does not follow the overall patterns presented by the rest of the data. We refer to such observations as outliers. Suppose, for example, that almost all BMI values in our sample are between 20 and 40. Observing a BMI value of 50 would be suspicious. Further investigation might reveal that in fact this is the correct value of BMI for an individual in our sample. In this case, this outlier is a legitimate value. However, a BMI value of 500 or -50 is clearly an erroneous observation, which is possibly due to a data entry mistake.

# %% [markdown]
# We could identify outliers using data xploration techniques. As an example, we use the AsthmaLOS data collected by [12] to study the length of stay in hospital for asthmatic children in the USA.
#
# The variables in this data sets are:
#
# * **los:** length of stay in hospital (in days).
# * **hospital.id:** hospital ID.
# * **insurer:** the insurer, which is either 0 or 1.
# * **age:** the age of the patient.
#
# * **gender:** the gender of the patient; 1 for female, and 0 for male.
#
# * **race:** the race of the patient; 1 for white, 2 for Hispanic, 3 for African-American, 4 for Asian/Pacific Islander, 5 for others.
#
# * **bed.size:** the number of beds in the hospital; 1 means 1 to 99, 2 means 100 to 249, 3 means 250 to 400, 4 means 401 to 650.
#
# * **owner.type:** the hospital owner; 1 for public, 2 for private.
#
# * **complication:** if there were any treatment complication; 0 means there were no complications, 1 means there were some complications.
#
# From this list of variables, we can look for any errors. One approach is to look for inappropiate data values. This approach is demonstrated in Example 4.

# %% [markdown]
# ## Example 4: Print Unique Values
#
# "Real data" often contains some number of bad values that can have a serious impact on data analysis. One type of data entry error is the inclusion of an inappropiate data value. To look for this kind of error, the code in the cell below prints outs all of the _unique_ values in a selected DataFrame column. Since a real data set may contain hundreds, thousands or more entries, we don't want to look at all of the values, just the unique ones.
#
# The code in Example 4 prints out the unique values in the column `race` from the `birthwt` data set.

# %%
# @title Example 4: Print Unique Values

import pandas as pd

# Define variables
col_name = "race"       # Column name

# Print unique values (sorted)
print(sorted(df_bwt[col_name].unique()))
# Out:
# ['black', 'other', 'white']

# %% [markdown]
# If the code is correct, you should see the following output:
#
# ```text
# ['black', 'other', 'white']
# ```

# %% [markdown]
# This agrees with stated list of possible values for the variable `race` in the `birthwt` data set, so there are no inappropiate values.

# %% [markdown]
# ## **Exercise 4: Print Unique Variables**
#
# In the cell below, write the Python code to find all of the unique values for the variable `gender` in the `AsthmaLOS` data set.
#
# **Code Hints:**
#
# 1. Copy-and-paste Example 4 into the space below.
# 2. Change the variables to match this code block:
# ```Python
# # Define variables
# col_name = "gender"    # Column name
# ```
# 3. Change every instance of `df_bwt` to `df_asthma`.

# %%
# @title Exercise 4: Print Unique Values

import pandas as pd

# Define variables
col_name = "gender"     # Column name

# Print unique values (sorted)
print(sorted(df_asthma[col_name].unique()))
# Out:
# [np.int64(0), np.int64(1), np.int64(4)]

# %% [markdown]
# If the code is correct, you should see the following output:
# ```text
# [np.int64(0), np.int64(1), np.int64(4)]
# ```

# %% [markdown]
# The output indicates that three different values were found in the `gender` column, $0$, $1$ and $4$. However, the `gender` variable can take only two values, $0$ for male and $1$ for female. That the data included observations whose values for gender is "4" means these values were entered by mistake. They should be either removed (as described above) or corrected if possible. If we know the correct values for these observations (e.g., by examining the medical records), we can edit the data and keep the observations.

# %% [markdown]
# A visual method for locating outliers is the generation of _boxplots_ as was demonstrated the previous lecture (Chapter_02A). Example 5 provides a review.

# %% [markdown]
# ## Example 5: Create a Boxplot
#
# The code in the cell below shows how to create a boxplot using Python. In this example, the boxplot shows the distribution of the birthweight variable (`bwt`) in the `birthwt_df` DataFrame.

# %%
# @title Example 5: Create a Boxplot

import matplotlib.pyplot as plt

# Define variables
col_name = "bwt"

# Generate the boxplot
plt.boxplot(df_bwt[col_name])

# Display the boxplot
plt.show()

# %% [markdown]
# If the code is correct, you should see the following output:
#
# ![__](https://biologicslab.co/STA1403/images/chapter_02/chapter_02A_image05B.png)

# %% [markdown]
# In boxplot figures, open circle are typically used to represent an **outlier** -- a data value that falls significantly outside the overall pattern of the distribution. It is usually defined using the Interquartile Range (IQR) method:
#
# Lower Fence = Q1 − 1.5 × IQR
# Upper Fence = Q3 + 1.5 × IQR
#
# In the example shown in the output above, there is one `bwt` value that is suspiciously low, slightly below the Lower Frence.

# %% [markdown]
# ## **Exercise 5: Create a Boxplot**
#
# In the cell below, write the Python code to create a boxplot to show the distribution of the variable `los` (length of stay) in the `df_asthma` DataFrame.
#
# **Code Hints:**
#
# 1. Copy-and-paste Example 5 into the cell below.
# 2. Change the variables to read as shown in this code block:
# ```Python
# # Define variables
# col_name = "los"
# ```
# 3. Change every instance of `df_bwt` to `df_astham`.

# %%
# @title Exercise 5: Create a Boxplot

import matplotlib.pyplot as plt

# Define variables
col_name = "los"

# Generate the boxplot
plt.boxplot(df_asthma[col_name])

# Display the boxplot
plt.show()

# %% [markdown]
# If the code is correct, you should see the following output:
#
# ![__](https://biologicslab.co/STA1403/images/chapter_02/chapter_02B_image06B.png)

# %% [markdown]
# As we can see, there are two children
# whose length of stay is extremely large ($50$ and $58$). These values are not consistent
# with the rest of data. (All other values are less than $10$.) However, if we find that
# they are legitimate and correctly recorded values, we should keep them in our data
# since they provide important information on the distribution of the variable (e.g.,
# how extreme could be). Of course, such observations can drastically affect our re-
# sults. For analyzing such data, we could use statistical methods that are more robust
# against outliers (e.g., median, IQR).

# %% [markdown]
# ### **_2.5.3 Data Transformation_**
#
# Occasionally, we rely on data transformation techniques (i.e., applying a function to the variable) to reduce the influence of extreme values in our analysis. Two of the most commonly used transformation functions for this purpose are logarithm and square root. The logarithm function, $ \log(x) $ , is usually used to transform right-skewed variables with positive values. The square root function is usually used for right-skewed count variables. We use these transformations to reduce the skewness, i.e., to make it more symmetric, and reduce the influence of extreme values.

# %% [markdown]
# ## Example 6 - Step 1: Log(x) Transform
#
# The code in the cell below first creates a copy of the DataFrame, `df_bwt` to make `df_bwt_log` and then adds the log values of the selected column to `df_bwt_log`.

# %%
# @title Example 6 - Step 1: Log(x) Transform

import pandas as pd
import numpy as np

# Define variables
colName1 = "lwt"       # Column to be transformed
colName2 = "log-lwt"   # Name of new transformed column

# Make a local copy
df_bwt_log = df_bwt.copy()

# Compute the log of the values in colName1 and add it to a new column, colName2
df_bwt_log[colName2] = np.log(df_bwt_log[colName1])

# Display the first few rows to verify
print(df_bwt_log.head())
# Out:
#    low  age    lwt   race  smoke  ptl  ht  ui  ftv   bwt   log-lwt
# 0    0   19  182.0  black      0    0   0   1    0  2523  5.204007
# 1    0   33  155.0  other      0    0   0   0    3  2551  5.043425
# 2    0   20  105.0  white      1    0   0   0    1  2557  4.653960
# 3    0   21  108.0  white      1    0   0   1    2  2594  4.682131
# 4    0   18  107.0  white      1    0   0   1    0  2600  4.672829

# %% [markdown]
# If the code is correct, you should see the following output:
# ```text
#    low  age    lwt   race  smoke  ptl  ht  ui  ftv   bwt   log-lwt
# 0    0   19  182.0  black      0    0   0   1    0  2523  5.204007
# 1    0   33  155.0  other      0    0   0   0    3  2551  5.043425
# 2    0   20  105.0  white      1    0   0   0    1  2557  4.653960
# 3    0   21  108.0  white      1    0   0   1    2  2594  4.682131
# 4    0   18  107.0  white      1    0   0   1    0  2600  4.672829
# ```

# %% [markdown]
# ## Example 6 - Step 2: Log(x) Transform
#
# We want to use the log(x) transform to convert our right-skewed density histogram into a more symetrical one. The code in the cell below plots the orignal density histogram of `lwt` on the left, and the density histogram of `log-lwt` on the right.

# %%
# @title Example 6 - Step 2: Log(x) Transform

import matplotlib.pyplot as plt
import numpy as np

# Define variables
colName1 = "lwt"         # Name of the column to tranform
colName2 = "log-lwt"     # Name of new, transformed column

# Make a local copy
df_bwt_log = df_bwt.copy()

# Compute the log of the values in colName1 and add it to a new column, colName2
df_bwt_log[colName2] = np.log(df_bwt_log[colName1])

# Create a figure with 1 row and 2 columns
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

# Left side: Density Histogram of 'lwt'
ax1.hist(df_bwt_log[colName1], bins=8, density=True, edgecolor='black')
ax1.set_title(f'Density Histogram of {colName1}')
ax1.set_xlabel(colName1)
ax1.set_ylabel('Density')

# Right side: Density of log(lwt)
ax2.hist(df_bwt_log[colName2], bins=8, density=True, edgecolor='black')
ax2.set_title(f'Density Histogram of {colName2}')
ax2.set_xlabel(f'log{colName1}')
ax2.set_ylabel('Density')

plt.tight_layout()
plt.show()

# %% [markdown]
# If your code is correct, you should see the following output:
#
# ![__](https://biologicslab.co/STA1403/images/chapter_02/chapter_02B_image05B.png)

# %% [markdown]
# Compare the data distribution (i.e. "shape") of the original values for the variable `lwt` in the density histogram shown in the left panel, with the histogram on the right in which the log of the `lwt` values have been plotted. While the distribution in the left panel is clearly right-skewed, the right panel is less skewed and more symmetric. In short, using the log(x) transform on the `lwt` values creates a more symmetrical density histogram (right panel).

# %% [markdown]
# ## **Exercise 6 - Step 1: Log(x) Transform**
#
# Unlike the right-skewed values in the column `lwt`, the values in the column `bwt` showed a more symmetrical distribution. This raises the question of what would happen if you perform a logarithmic transform on a "normally" distributed variable?
#
# **Code Hints:**
#
# 1. Copy-and-paste Example 6 - Step 1 into the cell below.
# 2. Change the variables to read as shown in the following code block:
# ```Python
# # Define variables
# colName1 = "bwt"        # Column to be transformed
# colName2 = "log-bwt"    # Name of new transformed column
# ```

# %%
# @title Exercise 6 - Step 1: Log(x) Transform

import pandas as pd
import numpy as np

# Define variables
colName1 = "bwt"        # Column to be transformed
colName2 = "log-bwt"    # Name of new transformed column

# Make a local copy
df_bwt_log = df_bwt.copy()

# Compute the log of the values in colName1 and add it to a new column, colName2
df_bwt_log[colName2] = np.log(df_bwt_log[colName1])

# Display the first few rows to verify
print(df_bwt_log.head())
# Out:
#    low  age    lwt   race  smoke  ptl  ht  ui  ftv   bwt   log-bwt
# 0    0   19  182.0  black      0    0   0   1    0  2523  7.833204
# 1    0   33  155.0  other      0    0   0   0    3  2551  7.844241
# 2    0   20  105.0  white      1    0   0   0    1  2557  7.846590
# 3    0   21  108.0  white      1    0   0   1    2  2594  7.860956
# 4    0   18  107.0  white      1    0   0   1    0  2600  7.863267

# %% [markdown]
# If your code is correct, you should see the following output:
# ```text
#    low  age    lwt   race  smoke  ptl  ht  ui  ftv   bwt   log-bwt
# 0    0   19  182.0  black      0    0   0   1    0  2523  7.833204
# 1    0   33  155.0  other      0    0   0   0    3  2551  7.844241
# 2    0   20  105.0  white      1    0   0   0    1  2557  7.846590
# 3    0   21  108.0  white      1    0   0   1    2  2594  7.860956
# 4    0   18  107.0  white      1    0   0   1    0  2600  7.863267
#
# ```

# %% [markdown]
# ## **Exercise 6 - Step 2: Log(x) Transform**
#
# Let's see what your logarithmic transform did. In the cell below write the code to display a density histogram of the variable `bmt` on the left side, and a density histogram of `log-bwt` on the right side. Remember, the distribution of the variable `bmt` was already symmetric before any transformation.
#
# **Code Hints:**
#
# 1. Copy-and-paste Example 6 - Step 2 into the cell below.
# 2. Change the variables to read as shown in this code block:
# ```Python
# # Define variables
# colName1 = "bwt"         # Name of the column to tranform
# colName2 = "log-bwt"     # Name of new, transformed column
# ```

# %%
# @title Exercise 6 - Step 2: Log(x) Transform

import matplotlib.pyplot as plt
import numpy as np

# Define variables
colName1 = "bwt"         # Name of the column to tranform
colName2 = "log-bwt"     # Name of new, transformed column

# Make a local copy
df_bwt_log = df_bwt.copy()

# Compute the log of the values in colName1 and add it to a new column, colName2
df_bwt_log[colName2] = np.log(df_bwt_log[colName1])

# Create a figure with 1 row and 2 columns
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

# Left side: Density Histogram of 'lwt'
ax1.hist(df_bwt_log[colName1], bins=8, density=True, edgecolor='black')
ax1.set_title(f'Density Histogram of {colName1}')
ax1.set_xlabel(colName1)
ax1.set_ylabel('Density')

# Right side: Density of log(lwt)
ax2.hist(df_bwt_log[colName2], bins=8, density=True, edgecolor='black')
ax2.set_title(f'Density Histogram of {colName2}')
ax2.set_xlabel(f'log{colName1}')
ax2.set_ylabel('Density')

plt.tight_layout()
plt.show()

# %% [markdown]
# If your code is correct, you should see the following output:
#
# ![__](https://biologicslab.co/STA1403/images/chapter_02/chapter_02B_image04B.png)

# %% [markdown]
# As you can see from inspection, taking the logarithm of a symmetically distributed variable converts it into a left-skewed distribution as seen in the right panel.

# %% [markdown]
# ### **_2.5.4 Creating New Variable Based on Two or More Existing Variables_**
#
# In the previous chapter, we discussed creating new variables based on existing ones as a common data preprocessing step. Sometimes it is useful to create a new variable based on two or more existing variables. Consider the bodyfat data set, which includes weight and height. Using these two variables, we can calculate BMI for each person in the sample using the equation
#
# $$
# BMI = \frac {weight\times 7 0 3}{(h e i g h t) ^ {2}},
# $$
#
# where weight is in pounds, and height is in inches.

# %% [markdown]
# ### **_2.5.5 Creating Categories for Numerical Variables_**
#
# Another common preprocessing technique is to create categorical variables based on numerical variables. This could help us to see the patterns more clearly and identify relationships more easily. Recall that histograms are created by dividing the range of a numerical variable into intervals. Instead of using arbitrary intervals, we might prefer to group the values in a meaningful way.
#
# The code in Example 6 creates a categorical variable called `weight_status` based on an individual's body mass index (`bmi`) using the criteria published by the US Centers for Disease Control and Prevention (CDC).

# %% [markdown]
# ## Example 7: Create Categories for a Numerical Variable
#
# The code in the cell below creates a local copy of the `Pima_df` DataFrame called `eg_Pima_df`. The code then uses this local copy to create 4 categories for the numerical variable `bmi` and adds them to a new column called `weight_status`. These four categories are "Underweight" (less than 18.5), "Healthy Weight" (between 18.5 and 25.0), "Overweight" (between 25.0 and 30.0) and "Obese" (greater than 30.0).

# %%
datasetSaveName.head()
# Out:
#    npreg  glu  bp  skin   bmi    ped  age type weight_status
# 0      5   86  68    28  30.2  0.364   24   No       Obesity
# 1      7  195  70    33  25.1  0.163   55  Yes    Overweight
# 2      5   77  82    41  35.8  0.156   35   No       Obesity
# 3      0  165  76    43  47.9  0.259   26   No       Obesity
# 4      0  107  60    25  26.4  0.133   23   No    Overweight

# %%
# @title Example 7: Create Categories for a Numerical Variable

import pandas as pd

# Define variables
colName1 = "bmi"             # Numerical column
colName2 = "weight_status"   # New categorical column


# Define the bin edges
bins = [0, 18.5, 25, 30, float('inf')]

# Define the labels for the categories
labels = ['Underweight', 'Healthy Weight', 'Overweight', 'Obesity']

# Create a local copy of the DataFrame
df_pima_copy = df_pima.copy()

# Create the new column
df_pima_copy[colName2] = pd.cut(df_pima[colName1], bins=bins, labels=labels, right=False)

# Generate bar chart of new column
df_pima_copy[colName2].value_counts().sort_index().plot(kind='bar')

# Add labels and title
plt.xlabel(f"{colName2}")
plt.ylabel("Frequency")

# Rotate the x-axis labels to be horizontal
plt.xticks(rotation=0)

# Display the plot
plt.show()

# %% [markdown]
# If the code is correct, you should see the following output:
# ![__](https://biologicslab.co/STA1403/images/chapter_02/chapter_02B_image07B.png)

# %% [markdown]
# The graph of the `weight_status` variable clearly indicates that the “Obese” category in the `Pima.tr` data set contains the highest frequency of individuals in this particular population.

# %% [markdown]
# ## **Exercise 7: Create Categories for a Numerical Variable**
#
# In the cell below, creates a 4 categories for the numerical variable `bwt` in the `df_bwt` DataFrame. The categories are "Extremely Low", "Very Low", "Low" and "Normal".
#
# **Code Hints:**
#
# 1. Copy-and-paste Example 7 into the cell below
# 2. Change the variables, bin edges and the labels as shown in this code block:
# ```Python
# # Define variables
# colName1 = "bwt"                  # Numerical column
# colName2 = "birthweight_status"   # New categorical column
#
# # Define the bin edges
# bins = [0, 1500, 2500, 4000, float('inf')]
#
# # Define the labels for the categories
# labels = ["Extemely Low", "Very Low", "Low", "Normal"]
# ```
# 3. Change every instance of `df_pima` to `df_bwt`.

# %%
# @title Exercise 7: Create Categories for a Numerical Variable

import pandas as pd

# Define variables
colName1 = "bwt"                  # Numerical column
colName2 = "birthweight_status"   # New categorical column

# Define the bin edges
bins = [0, 1500, 2500, 4000, float('inf')]

# Define the labels for the categories
labels = ['Extemely Low', 'Very Low', 'Low', 'Normal']

# Create a local copy of the DataFrame
df_bwt_copy = df_bwt.copy()

# Create the new column
df_bwt_copy[colName2] = pd.cut(df_bwt[colName1], bins=bins, labels=labels, right=False)

# Generate bar chart of new column
df_bwt_copy[colName2].value_counts().sort_index().plot(kind='bar')

# Add labels and title
plt.xlabel(f"{colName2}")
plt.ylabel("Frequency")

# Rotate the x-axis labels to be horizontal
plt.xticks(rotation=0)

# Display the plot
plt.show()

# %% [markdown]
# If the code is correct, you should see the following output:
# ![__](https://biologicslab.co/STA1403/images/chapter_02/chapter_02B_image08B.png)

# %% [markdown]
# ## **2.6 Advanced**

# %% [markdown]
# ### **_2.6.1 Coefficient of Variation_**
#
# Suppose that we want to compare the dispersion of `bwt` to that of `lwt` using their standard deviations.
# After changing the measurement unit from grams to pounds, the standard deviation changes from 729.2 to 1.6. Now, this is much smaller than the standard deviation of `lwt`, which is 30.6. This is of course expected since the values of `lwt` are much larger than the values of `bwt.lb` expressed in 1bs. As a result, `lwt` has much larger sample mean and larger deviations around the mean compared to `bwt.lb`.
#
# This illustratea how difference in measurement units and large differences in sample means make it difficult to compare variables based on their standard deviations. In many situations, we can avoid these issues by using another measure of variation called the **coefficient of variation** instead of standard deviation.
#
# > To quantify dispersion independently from units, we use the `coefficient of variation`, which is the standard deviation divided by the sample mean (assuming that the mean is a positive number):
#
# $$
# C V = \frac {s}{\bar {x}}.
# $$
#
# The coefficient of variation for `bwt` (birth weight in grams) is $729.2/2944.6 = 0.25$ and for `bwt.1b` (birth weight in pounds) is $1.6/6.5 = 0.25$. Therefore, the coefficient of variation is the same, even though `bwt` has a larger standard deviation compared to `bwt.1b`. Comparing this coefficient of variation to $30.6/129.8 = 0.24$, which is the coefficient of variation for lwt, suggests that the two variables have roughly the same dispersion in terms of CV. In general, the coefficient of variation is used to compare variables in terms of their dispersion when the means are substantially different (possibly as the result of having different measurement units).

# %% [markdown]
# ### **_2.6.2 Scaling and Shifting Variables_**
#
# To see why the coefficient of variation $ (CV = s/\bar{x}) $ is independent of measurement units in the above example, we need to learn about how the mean and standard deviation change when we change the scale of a variable. For example, we changed the scaled of bwt by multiplying it by the constant 1/453.6 (i.e., dividing it by 453.6).
#
# In general, when we multiply the observed values of a variable by a constant $a$, its mean, standard deviation, and variance are multiplied by $a$, $|a|$, and $a^{2}$, respectively. That is, if $y = ax$, then
#
# $$
# \begin{array}{l} \bar {y} = a \bar {x}, \\ s _ {y} = | a | s _ {x}, \\ s _ {y} ^ {2} = a ^ {2} s _ {x} ^ {2}, \\ \end{array}
# $$
#
# where $\bar{x}$, $s_{x}$, and $s_{x}^{2}$ are the sample mean, standard deviation, and variance of the original observations $x$, and $\bar{y}$, $s_{y}$, and $s_{y}^{2}$ are the sample mean, standard deviation, and variance of scaled observations $y$.
#
# In the above example, the mean and standard deviation of bwt (denoted x) were $\bar{x}=2944.6$ and $s_{x}=729.2$, respectively (Fig. 2.22). To convert the measurement unit to pounds, we multiplied bwt by $a=1/453.6$ to create a new variable bwt. lb (denoted y). The mean and standard deviation of bwt. lb are therefore as follows:
#
# $$
# \begin{array}{l} \bar {y} = \frac {1}{4 5 3 . 6} \times 2 9 4 4. 6 = 6. 5, \\ s _ {y} = | a | s _ {x} = \frac {1}{4 5 3 . 6} \times 7 2 9. 2 = 1. 6, \\ \end{array}
# $$
#
# which are the same values as what we obtained by using R-Commander (Fig. 2.36).
#
# When the measurement units are changed by multiplying the observed values by a positive constant (e.g., multiplying by 1/453.6 in the above example to convert grams to pounds), the coefficient of variation is not affected since both mean and standard deviation will be multiplied by that number. If $y = ax$ (where $a$ is a positive constant), then
#
# $$
# C V _ {y} = \frac {s _ {y}}{\bar {y}} = \frac {a s _ {x}}{a \bar {x}} = \frac {s _ {x}}{\bar {x}} = C V _ {x}.
# $$
#
# What happens if instead of scaling the observed value, we shift them by a constant b (which can be negative): $y = x + b$? For example, suppose after researchers collected the birthwt data set, they realized that the weighting scale they used to measure birth weight was not calibrated properly, and they need to add 20 grams to the weight of each child, i.e., $y = x + 20$. Therefore, all the observed values for bwt will be shifted upwards by 20 points. Intuitively, this shifts the sample mean by 20 points. However, since the difference between observed values and the mean do not change, the standard deviation and variance remain unchanged. In general, if we shift the observed values by b, i.e., $y = x + b$, then
#
# $$
# \begin{array}{l} \bar {y} = \bar {x} + b, \\ s _ {y} = s _ {x}, \\ s _ {y} ^ {2} = s _ {x} ^ {2}. \\ \end{array}
# $$

# %% [markdown]
# If we multiply the observed values by the constant $a$ and then add the constant $b$ to the result, i.e., $y = ax + b$, then
#
# $$
# \bar {y} = a \bar {x} + b,
# $$
#
# $$
# s _ {y} = | a | s _ {x},
# $$
#
# $$
# s _ {y} ^ {2} = a ^ {2} s _ {x} ^ {2}.
# $$
#
# Therefore, when changing measurement units involved adding a constant (e.g., adding 273.15 to convert Celsius to Kelvin), the coefficient of variation will change. If $ y = ax + b $ (assuming $ a > 0 $ and $ b \neq 0 $), then
#
# $$
# C V _ {y} = \frac {s _ {y}}{\bar {y}} = \frac {a s _ {x}}{a \bar {x} + b} \neq \frac {s _ {x}}{\bar {x}}.
# $$

# %% [markdown]
# ### **_2.6.3 Variable Standardization_**
#
# **Variable standardization** is a common linear transformation, where we subtract the sample mean $ \bar{x} $ from the observed values and divide the result by the sample standard deviation s, in order to shift the mean to zero and make the standard deviation 1:
#
# $$
# y _ {i} = \frac {x _ {i} - \bar {x}}{s}.
# $$
#
# Using such transformation is especially common in regression analysis (Chap. 11) and clustering (Sect. 12.1). Following the rules we discussed above, subtracting $ \bar{x} $ from the observations shifts the sample mean to zero. This, however, does not change the standard deviation. Dividing by s, on the other hand, changes the sample standard deviation to 1. The mean is also divided by s. However, since the sample mean has become zero after subtracting $ \bar{x} $ , it remains zero. Therefore, variable standardization creates a new variable with mean 0 and standard deviation 1.
#
# Suppose that we want to standardize a numerical variable using Python. Example 8 show an example of how to standardize the variable `lwt` in the `birthwt` data set.

# %% [markdown]
# ## Example 8: Standardize Numerical Variables
#
# To standardize a variable like `lwt`. we only need to perform two mathematical operations on every value:
#
# * **subtract the mean**
# * **divide by the standard deviation**.
#
# The code in the cell below creates a local copy of the `birthwt_df` DataFrame called `std_birthwt_df` and standardizes all of the numerical variables in this local copy.

# %%
# @title Example 8: Standardize Numerical Variables

import pandas as pd
from sklearn.preprocessing import StandardScaler

# Define variables
colName = "number"

# Initialize the StandardScaler
scaler = StandardScaler()

# Make a local copy
df_bwt_standard = df_bwt.copy()

# Select only the numerical columns
numerical_cols = df_bwt_standard.select_dtypes(include =[colName]).columns

# Apply standardization to the numerical columns
df_bwt_standard[numerical_cols] = scaler.fit_transform(df_bwt_standard[ numerical_cols])

# Display the result
print(df_bwt_standard.head())
# Out:
#         low       age       lwt   race     smoke       ptl        ht  \
# 0 -0.673681 -0.801965  1.720829  black -0.802171 -0.397872 -0.260378
# 1 -0.673681  1.847222  0.830492  other -0.802171 -0.397872 -0.260378
# 2 -0.673681 -0.612737 -0.818279  white  1.246617 -0.397872 -0.260378
# 3 -0.673681 -0.423509 -0.719353  white  1.246617 -0.397872 -0.260378
# 4 -0.673681 -0.991192 -0.752328  white  1.246617 -0.397872 -0.260378
#
#          ui       ftv       bwt
# 0  2.397916 -0.751222 -0.579922
# 1 -0.417029  2.088396 -0.541412
# 2 -0.417029  0.195318 -0.533160
# 3  2.397916  1.141857 -0.482272
# 4  2.397916 -0.751222 -0.474020

# %% [markdown]
# If the code is correct, you should see the following output:
# ```text
#         low       age       lwt   race     smoke       ptl        ht  \
# 0 -0.673681 -0.801965  1.720829  black -0.802171 -0.397872 -0.260378
# 1 -0.673681  1.847222  0.830492  other -0.802171 -0.397872 -0.260378
# 2 -0.673681 -0.612737 -0.818279  white  1.246617 -0.397872 -0.260378
# 3 -0.673681 -0.423509 -0.719353  white  1.246617 -0.397872 -0.260378
# 4 -0.673681 -0.991192 -0.752328  white  1.246617 -0.397872 -0.260378
#
#          ui       ftv       bwt
# 0  2.397916 -0.751222 -0.579922
# 1 -0.417029  2.088396 -0.541412
# 2 -0.417029  0.195318 -0.533160
# 3  2.397916  1.141857 -0.482272
# 4  2.397916 -0.751222 -0.474020
# ```

# %% [markdown]
# You should notice that standardized values are rather small values that are both positive and negative numbers. We will examine this item more fully in Example 8.

# %% [markdown]
# ## **Exercise 8: Standardize Numerical Variables**
#
# In the cell below, write the code to standardize the numerical data in the `Pima.tr` data set.
#
# **Code Hints:**
#
# 1. Copy-and-paste Example 8 into the cell below.
# 2. Change the variables so they read as shown in this code block:
# ```Python
# # Define variables
# colName = "number"
# ```
# 3. Change every instance of `df_bwt` to `df_pima`.

# %%
# @title Exercise 8: Standardize Numerical Variables

import pandas as pd
from sklearn.preprocessing import StandardScaler

# Define variables
colName = "number"

# Initialize the StandardScaler
scaler = StandardScaler()

# Make a local copy
df_pima_standard = df_pima.copy()

# Select only the numerical columns
numerical_cols = df_pima_standard.select_dtypes(include =[colName]).columns

# Apply standardization to the numerical columns
df_pima_standard[numerical_cols] = scaler.fit_transform(df_pima_standard[ numerical_cols])

# Display the result
print(df_pima_standard.head())
# Out:
#       npreg       glu        bp      skin       bmi       ped       age type
# 0  0.425869 -1.202040 -0.284695 -0.103888 -0.347103 -0.315755 -0.740777   No
# 1  1.021490  2.248642 -0.110035  0.323636 -1.181327 -0.971641  2.090800  Yes
# 2  0.425869 -1.486959  0.937920  1.007674  0.568908 -0.994483  0.263976   No
# 3 -1.063183  1.298913  0.413942  1.178684  2.548147 -0.658382 -0.558095   No
# 4 -1.063183 -0.537230 -0.983331 -0.360403 -0.968682 -1.069534 -0.832118   No

# %% [markdown]
# If your code iss correct, you should see the following output:
# ```text
#       npreg       glu        bp      skin       bmi       ped       age type
# 0  0.425869 -1.202040 -0.284695 -0.103888 -0.347103 -0.315755 -0.740777   No
# 1  1.021490  2.248642 -0.110035  0.323636 -1.181327 -0.971641  2.090800  Yes
# 2  0.425869 -1.486959  0.937920  1.007674  0.568908 -0.994483  0.263976   No
# 3 -1.063183  1.298913  0.413942  1.178684  2.548147 -0.658382 -0.558095   No
# 4 -1.063183 -0.537230 -0.983331 -0.360403 -0.968682 -1.069534 -0.832118   No
# ```

# %% [markdown]
# # **Electronic Submission**
#
# When you run the code in the cell below, it will grade your Colab notebook and tell you your pending grade as it currently stands. You will be given the choice to either submit your notebook for final grading or the option to continue your work on one (or more) Exercises.
#
# Grant Access to your Colab Secrets if you are asked to do so.

# %%
# @title Electronic Submission

import urllib.request
import ssl
import time

url = "https://biologicslab.co/STA1403/backend_code/validate.py?v=" + str(time.time())

ctx = ssl.create_default_context()
ctx.check_hostname = False
ctx.verify_mode = ssl.CERT_NONE

req = urllib.request.Request(
    url,
    headers={
        "Cache-Control": "no-cache, no-store, must-revalidate",
        "Pragma": "no-cache",
        "Expires": "0"
    }
)

with urllib.request.urlopen(req, context=ctx) as r:
    exec(r.read().decode("utf-8"))

main()
# Out:
# Credentials Check
# UTSA ID: gie856 ✅
# STA1403  Key  ✅
# Notebook: CHAPTER_02B
# ...
# Notebook collected ✅  (260,911 bytes)
#
# Grading notebook — this may take a moment…
# ✅  Preliminary grading complete  (ID: STA1403_6a4810a48a984)
#
# ...
#   Preliminary Submission Score Report
# ...
#
#   Exercise      Score   Output  Status
#   --------------------------------------------
#   ✅  Exercise 1A    100%   [text]   correct
#   ✅  Exercise 1B    100%   [text]   correct
#   ✅  Exercise 2     100%   [text]   correct
#   ✅  Exercise 3     100%   [text]   correct
#   ✅  Exercise 4     100%   [text]   correct
#   ✅  Exercise 5     100%   [image]  correct
#   ✅  Exercise 6-STEP1  100%   [text]   correct
#   ✅  Exercise 6-STEP2  100%   [image]  correct
#   ✅  Exercise 7     100%   [image]  correct
#   ✅  Exercise 8     100%   [text]   correct
#
#   ────────────────────────────────────────────────
#   OVERALL SCORE: 100%  (A)
#   ✅  All exercises completed correctly!
# ...
# Output()
